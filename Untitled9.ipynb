# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikolas9808/C/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Cargar el JSON
df = pd.read_json('/content/TelecomX_Data.json')

# Normalizar todas las columnas anidadas
df_normalizado = pd.json_normalize(
    df.to_dict(orient='records'),  # convierte a lista de dicts
    sep='.'  # para nombres de columnas tipo 'account.Charges.Monthly'
)

#Mostrar las primeras filas
#print(df_normalizado.head(20))
#df_normalizado.info()
#df_normalizado.describe()

df_normalizado['account.Charges.Monthly'] = pd.to_numeric(
    df_normalizado['account.Charges.Monthly'], errors='coerce'
)
# Crear columna con valor diario estimado
df_normalizado['Cuentas_Diarias'] = df_normalizado['account.Charges.Monthly'] / 30.44

df_normalizado['Cuentas_Diarias'] = df_normalizado['Cuentas_Diarias'].round(2)

df_normalizado
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
# Convertir a valores numéricos (si no lo has hecho ya)
df_normalizado['account.Charges.Total'] = pd.to_numeric(df_normalizado['account.Charges.Total'], errors='coerce')
df_normalizado['account.Charges.Monthly'] = pd.to_numeric(df_normalizado['account.Charges.Monthly'], errors='coerce')
df_normalizado['customer.tenure'] = pd.to_numeric(df_normalizado['customer.tenure'], errors='coerce')
df_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %%
#df_normalizado.columns
df_normalizado1 = df_normalizado.drop(columns= 'customerID', axis=[1])
df_normalizado1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      7267 non-null   object
#  1   customer.gender            7267 non-null   object
#  2   customer.SeniorCitizen     7267 non-null   int64
#  3   customer.Partner           7267 non-null   object
#  4   customer.Dependents        7267 non-null   object
#  5   customer.tenure            7267 non-null   int64
#  6   phone.PhoneService         7267 non-null   object
#  7   phone.MultipleLines        7267 non-null   object
#  8   internet.InternetService   7267 non-null   object
#  9   internet.OnlineSecurity    7267 non-null   object
#  10  internet.OnlineBackup      7267 non-null   object
#  11  internet.DeviceProtection  7267 non-null   object
#  12  internet.TechSupport       7267 non-null   object
# ...

# %%
# Encontrar columnas con exactamente 2 valores únicos (excluyendo NaN)
binarias = [col for col in df_normalizado1.columns if df_normalizado1[col].nunique(dropna=True) == 2]

print("Columnas con solo dos categorías:", binarias)


# Transformar cada una a 0 y 1
for col in binarias:
    valores = list(df_normalizado1[col].dropna().unique())
    # Asignar el primer valor como 0 y el segundo como 1
    mapping = {valores[0]: 0, valores[1]: 1}
    df_normalizado1[col] = df_normalizado1[col].map(mapping)

# Verificar

print(df_normalizado1.head())
df_normalizado1.info()
# Out:
# Columnas con solo dos categorías: ['customer.gender', 'customer.SeniorCitizen', 'customer.Partner', 'customer.Dependents', 'phone.PhoneService', 'account.PaperlessBilling']
#   Churn  customer.gender  customer.SeniorCitizen  customer.Partner  \
# 0    No                0                       0                 0
# 1    No                1                       0                 1
# 2   Yes                1                       0                 1
# 3   Yes                1                       1                 0
# 4   Yes                0                       1                 0
#
#    customer.Dependents  customer.tenure  phone.PhoneService  \
# 0                    0                9                   0
# 1                    1                9                   0
# 2                    1                4                   0
# 3                    1               13                   0
# 4                    1                3                   0
#
# ...

# %%
categoricas = ['phone.MultipleLines','internet.InternetService','internet.OnlineSecurity','internet.OnlineBackup','internet.DeviceProtection','internet.TechSupport','internet.StreamingTV','internet.StreamingMovies','account.Contract', 'account.PaymentMethod']
datos_codificados =pd.get_dummies(data=df_normalizado1,columns=categoricas, dtype=int)

datos_codificados.sample(5)
# Out:
#      Churn  customer.gender  customer.SeniorCitizen  customer.Partner  \
# 6098    No                1                       0                 0
# 2429                      0                       1                 0
# 3746    No                1                       0                 0
# 4811    No                1                       0                 1
# 1033   Yes                0                       0                 1
#
#       customer.Dependents  customer.tenure  phone.PhoneService  \
# 6098                    0               12                   0
# 2429                    1                2                   0
# 3746                    1               37                   0
# 4811                    0               15                   0
# 1033                    1               10                   0
#
#       account.PaperlessBilling  account.Charges.Monthly  \
# 6098                         1                    26.40
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# Remove rows where 'Churn' is an empty string
datos_codificados = datos_codificados[datos_codificados['Churn'] != '']

X = datos_codificados.drop(['Churn'],axis=1)
y = datos_codificados['Churn']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=32)

modelo = DecisionTreeClassifier()
modelo.fit(X_train,y_train)
print(f'La exactitud del modelo con el conjunto de entrenamiento es de: {modelo.score(X_train,y_train)}')
print(f'La exactitud del modelo con el conjunto de validación es de: {modelo.score(X_test,y_test)}')
# Out:
# La exactitud del modelo con el conjunto de entrenamiento es de: 0.9975659229208925
# La exactitud del modelo con el conjunto de validación es de: 0.7363937529578798

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_previsto = modelo.predict(X_test)
print(f'La precisión del modelo es: {precision_score(y_test,y_previsto, pos_label="Yes")}')
print(f'La sensibilidad (Recall) del modelo es: {recall_score(y_test,y_previsto, pos_label="Yes")}')
print(f'La exactitud (accuracy) del modelo es: {accuracy_score(y_test,y_previsto)}')
print(f'El F1-score del modelo es: {f1_score(y_test,y_previsto, pos_label="Yes")}')
# Out:
# La precisión del modelo es: 0.49324324324324326
# La sensibilidad (Recall) del modelo es: 0.5318761384335154
# La exactitud (accuracy) del modelo es: 0.7363937529578798
# El F1-score del modelo es: 0.5118317265556529

# %%
from sklearn.model_selection import KFold, cross_validate

modelo = DecisionTreeClassifier(max_depth=10)
kf = KFold(n_splits=5, shuffle=True,random_state=5)
cv_resultados =cross_validate(modelo,X,y,cv=kf,scoring={'recall': make_scorer(recall_score, pos_label='Yes')})
cv_resultados
# Out:
# {'fit_time': array([0.08178282, 0.05976033, 0.05491352, 0.05447364, 0.05797482]),
#  'score_time': array([0.01392102, 0.01330161, 0.0123148 , 0.01169157, 0.02175641]),
#  'test_recall': array([0.46467391, 0.53626943, 0.53964194, 0.55898876, 0.48913043])}

# %%
from imblearn.over_sampling import SMOTE
import numpy as np

# Fill missing values in 'account.Charges.Total' with the mean
if 'account.Charges.Total' in X.columns:
    X['account.Charges.Total'].fillna(X['account.Charges.Total'].mean(), inplace=True)

oversampling = SMOTE()
x_balanceada,y_balanceada = oversampling.fit_resample(X,y)

y_balanceada.value_counts(normalize=True)
# Out:
# /tmp/ipython-input-3602285419.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['account.Charges.Total'].fillna(X['account.Charges.Total'].mean(), inplace=True)
# Churn
# No     0.5
# Yes    0.5
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.metrics import recall_score, make_scorer
import numpy as np

modelo = DecisionTreeClassifier(max_depth=10)
skf = StratifiedKFold(n_splits=5, shuffle=True,random_state=5)
cv_resultados =cross_validate(modelo,x_balanceada,y_balanceada,cv=skf,scoring={'recall': make_scorer(recall_score, pos_label='Yes')})

def intervalo_confianza(resultados):
  promedio = resultados['test_recall'].mean()
  desvio_std = resultados['test_recall'].std()
  return f'El intervalo de confianza es: [{promedio-2*desvio_std},{min(promedio+2*desvio_std,1)}]'

intervalo_confianza(cv_resultados)
# Out:
# 'El intervalo de confianza es: [0.8234235620632372,0.8588332334590533]'

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.metrics import recall_score, make_scorer
import numpy as np

# Definir y entrenar el modelo con los datos balanceados
modelo = DecisionTreeClassifier(max_depth=10)
modelo.fit(x_balanceada, y_balanceada)

# Tomar una muestra de los datos balanceados para simular nuevos datos
datos_nuevos_ejemplo = x_balanceada.sample(5, random_state=42)

# Asegurarse de que las columnas estén en el mismo orden que los datos de entrenamiento
datos_nuevos_ejemplo = datos_nuevos_ejemplo[X.columns]

# Realizar predicciones
predicciones = modelo.predict(datos_nuevos_ejemplo)

print("Ejemplo de nuevos datos:")
display(datos_nuevos_ejemplo)

print("\nPredicciones del modelo:")
print(predicciones)

# Obtener las etiquetas reales de los datos de ejemplo
# Nota: 'y_balanceada' es una Serie, necesitamos obtener los valores correspondientes a la muestra
etiquetas_reales = y_balanceada.loc[datos_nuevos_ejemplo.index]

print("\nComparación de predicciones vs. real:")
comparacion = pd.DataFrame({'Real': etiquetas_reales, 'Predicción': predicciones})
comparacion['Correcto'] = comparacion['Real'] == comparacion['Predicción']
display(comparacion)
# Out:
# Ejemplo de nuevos datos:
#       customer.gender  customer.SeniorCitizen  customer.Partner  \
# 9428                0                       0                 0
# 4593                1                       0                 1
# 5379                0                       0                 1
# 8918                0                       0                 0
# 6448                0                       1                 1
#
#       customer.Dependents  customer.tenure  phone.PhoneService  \
# 9428                    1                2                   0
# 4593                    1               25                   0
# 5379                    0                1                   0
# 8918                    1               23                   0
# 6448                    1               18                   0
#
#       account.PaperlessBilling  account.Charges.Monthly  \
# 9428                         0                70.638329
# 4593                         1                19.900000
# ...
